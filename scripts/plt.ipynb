# %%
import matplotlib.pyplot as plt
import seaborn as sns

large_sgx = [
    28043.551192,
    28047.986758,
    27951.798832,
    27954.474525,
    28007.727653,
    27943.346184,
    28001.522225,
    27967.474213,
    28005.444103,
]

large_sev = [897.6015, 918.8271000000001, 918.943, 909.1558000000001, 899.0495000000001, 901.434, 916.3495, 928.2095999999999, 923.5210999999999]

xs = ['$2^0$', '$2^1$', '$2^2$', '$2^3$', '$2^4$', '$2^5$', '$2^6$', '$2^7$', '$2^8$']
sgx = [299.773
,300.836
,309.647
,299.725
,300.768
, 299.007
,300.768
,303.346
,298.792]

sev = [ 458.983
,458.432
, 464.781
, 462.087
, 469.157
, 455.849
, 452.210
, 459.722
, 454.612]

ys = []

for i in range(len(xs)):
    ys.append(sgx[i])
    ys.append(large_sgx[i])

sns.set(style='whitegrid')

hue = ['\sf input = 100KB', '\sf input = 100MB'] * len(xs)
xs = [xs[i//2] for i in range(len(xs)*2)]
plt.rcParams['mathtext.default'] = 'sf'
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 24
plt.rc('legend', fontsize=24)
plt.xlabel('\sf Number of Pages')
plt.ylabel('\sf Time (ms)')


colors= ['royalblue', 'peru'] * len(xs)
g = sns.barplot(x=xs,y=ys, hue=hue, palette=['royalblue', 'peru'])
for bars, colors in zip(g.containers, (colors[0::2],colors[1::2])):
     for bar, color in zip(bars, colors):
          bar.set_facecolor(color)

# plt.ylim(200, 1200)
g.set_ylim(10**-2, 10**6)
g.set_yscale('log')
g.set_yticklabels(g.get_yticklabels(), fontsize=24)
g.set_xticklabels(g.get_xticklabels(), fontsize=24)

g.legend(bbox_to_anchor=(0.25, 1), loc='center left')
plt.savefig('./stack_sgx.pdf', bbox_inches='tight')
# Out:
# /tmp/ipykernel_1318752/2246111364.py:67: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_yticklabels(g.get_yticklabels(), fontsize=24)
