# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

xs = ['$2^0$', '$2^1$', '$2^2$', '$2^3$', '$2^4$', '$2^5$', '$2^6$', '$2^7$', '$2^8$']
sgx = [299.773
,300.836
,309.647
,299.725
,300.768
, 299.007
,300.768
,303.346
,298.792]

sev = [ 458.983
,458.432
, 464.781
, 462.087
, 469.157
, 455.849
, 452.210
, 459.722
, 454.612]

df = pd.DataFrame({
    'Page number (KB)': xs,
    'SEV': sev,
    'SGX': sgx,
})

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 12
plt.xlabel('Page number (KB)')
plt.ylabel('Time (ms)')
plt.ylim(200, 1000)
g = sns.lineplot(df)
g.set_xticks(range(len(df)))
g.set_xticklabels(xs)
plt.savefig('../stack.pdf', bbox_inches='tight')
